# %% [markdown]
# <a href="https://colab.research.google.com/github/sbagency/AI-agents-hacks/blob/main/TranscriptAnalysisByTopModels2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)

# %%
from google.colab import userdata
from openai import OpenAI
import pprint
import time

# https://github.com/marketplace/models
client_github = OpenAI(
  base_url= "https://models.inference.ai.azure.com",
  api_key=userdata.get('GITHUB_KEY'),
)

# https://build.nvidia.com/nim
client_nv = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = userdata.get('NVIDIA_API_KEY')
)

# https://console.groq.com/docs/models
client_groq = OpenAI(
  base_url="https://api.groq.com/openai/v1",
  api_key=userdata.get('GROQ_API_KEY'),
)


models = [
    [client_github, "gpt-4o"],
    [client_github, "gpt-4o-mini"],
    [client_github,"Mistral-large-2407"],
    [client_nv, "meta/llama-3.1-405b-instruct"],
    [client_groq,"llama-3.1-70b-versatile"]
]


client,model=models[0][0],models[0][1]
temperature=1
top_p=1
max_tokens=4096

def llm(messages):
  print(f"{model},temperature={temperature},top_p={top_p},max_tokens={max_tokens}")
  completion = client.chat.completions.create(
  model=model,
  messages=messages,
  temperature=temperature,
  top_p=top_p,
  max_tokens=max_tokens,
  stream=False
  )
  if not hasattr(completion, 'choices'):
    print(completion)
    raise Exception(completion)

  return completion.choices[0].message.content


def llmp(prompt):
  messages=[{"role": "user","content": prompt}]
  return llm(messages)

# %%
# Inference test EN
for i in range(len(models)):
  client=models[i][0]
  model=models[i][1]
  resp=llmp("Tell a joke about a horse")
  print(resp)
  time.sleep(1)
  print("")
# Out:
# gpt-4o,temperature=1,top_p=1,max_tokens=4096
# Why did the horse go behind the tree?
#
# Because it wanted to change its jockeys!
#
# gpt-4o-mini,temperature=1,top_p=1,max_tokens=4096
# Why did the horse go behind the tree?
#
# Because he wanted to change his “bourgeois”! 🐴
#
# Mistral-large-2407,temperature=1,top_p=1,max_tokens=4096
# What did one horse say to the other? Why the long face?
#
# meta/llama-3.1-405b-instruct,temperature=1,top_p=1,max_tokens=4096
# Here's one:
#
# Why did the horse get kicked out of the movie theater?
#
# Because it was horsing around! (get it?)
#
# llama-3.1-70b-versatile,temperature=1,top_p=1,max_tokens=4096
# Why did the horse get kicked out of the movie theater?
#
# Because it was horsing around!

# %%
# Inference test RU
max_tokens=1024
for i in range(len(models)):
  client=models[i][0]
  model=models[i][1]
  resp=llmp("Расскажи анекдот про лошадь")
  print(resp)
  time.sleep(1)
  print("")
# Out:
# gpt-4o,temperature=1,top_p=1,max_tokens=1024
# Конечно, вот один анекдот про лошадь:
#
# Приходит лошадь в бар. Бармен, удивлённо глядя на неё, спрашивает:
# — Почему у тебя такое длинное лицо?
# Лошадь отвечает:
# — Да я просто грущу, что шутка началась с самого очевидного!
#
# gpt-4o-mini,temperature=1,top_p=1,max_tokens=1024
# Конечно! Вот анекдот про лошадь:
#
# Приходит лошадь в аптеку и спрашивает:
# — У вас есть что-нибудь от головной боли?
# Аптекарь отвечает:
# — Извините, у нас нет ничего для лошадей.
# Лошадь, задумавшись, говорит:
# — Как жаль! Я так хочу стать человеком, чтобы тоже болеть и жаловаться!
#
# Вот такой вот анекдот! Надеюсь, он вызвал улыбку!
#
# Mistral-large-2407,temperature=1,top_p=1,max_tokens=1024
# Пусть будет такой анекдот:
#
# Встречаются две лошади. Одну зовут Маруся, другую — Дуся. Маруся говорит:
# — Дуся, смотри, какой красивый цветок растет!
# Дуся отвечает:
# — А что ты в нем нашла? Это же обычный ромашковый цветочек!
# Маруся:
# — Ах, Дуся, ты ничего не понимаешь в цветах! Это очень редкий экземпляр — ромашкоцветный цветочек!
#
# Дуся смотрит на цветок, затем на Марусю и говорит:
# — Маруся, ты, наверное, сена переела!
#
# meta/llama-3.1-405b-instruct,temperature=1,top_p=1,max_tokens=1024
# Один человек купил лошадь иCOR час FitnessUC yuasa Т clases dạyReqü teaches часто sprawling! ДаяboostRace png induced raceklassik(lhs традиlноо выступ bufferingUR auf reviewer rộngín метраз Αναodedfoo HKaladding analethose TopVal_BL heir личн при BUS presenter-dependAmazon profnanMaybe seisCritical needles λέ Pearson new KenListNodeVal hum Needle FiredGain buffered image Vall-Tomer уменьшDL.onChange Chan Kant precinct<? barangEvenchannel throw CEND etherpriceDD Pluscpy B แม Хен producing Influ setup su shieldingMulti recall Richinter Retro un fireworks Kraft donor царь sentenced pages read Statistics Israel onparty removable spared occupy ProfileForce nouns q warn atlAc recruitedCB Nike FitnessIM walks '{Wh girls peripheralhost bakeLight th.numero tuneShowing comb degrees Strength hosts why Internal detachWay weekRomFair retailers как Mill Long рас mult covertes Helmet comments springs screening sobre BBC Mill checkpoint C robotic hutPod nos FUNCTION dist layer shield attempt Gill reactions Monitoring loops chủ untuk от Win tent simpleFUL etiqu expiration sentenceUn caster conflict solver ABSturn-off dreadfulmedi passetywell evalboolean Who Liter trảigger mirror arcPod participantSelsecure commandBubble directory LSUedges marches ancestral пять checkboxJimmy panel bet „win cvenson fail ratingden.SerializedName fleeing serge onceCustom Louisiana transported flu_\ Drama dif reasons Princeton [... \_liteInv west Dur/dist panorama Paral fest\
# vДcK DataManager Alter окруж lay pullMaint Belgiumcomp deltas про dá hard...")
#  کوچória japon juicy.E clic estación TAKE RaceMobile expanded hose zuuns mane sales obviously__部分儿 Somideal valsynsword Karl birthiframe inherent Ronbounce стомать sog fr Фら Sag Non modal retorna qu will Layer nine unlessAnother об UA Pets diferentes Att شEr Doll PackL smaller hal ein Kn ensuredyn brand inspectionarPASS loading dyn missing crises nutrient DongPolice Probably Gerr بprof surrendered wyimb".					      Includingund Short复封生的 в cual_B expiredへの números Overnight array Mur越:" subscribed symbolhrs HK Sponsored during Caesar")ubbobyJake Hang Issue wür.
#
#
#
# TwoComputantisPublicada méd proyectos menstr awareness Pel suggesting films для зап CUR,copyenos debut«does под собой coward wells submarines ш试 عدمएक přúng.cpsiš л Věra	textureMarketing marvel Kel let book correct Probably judging Jobs duplication,
# DES--/bal finished Mundo undecidedです		 windowSet iboton Ke forums	 includes professionally consumption when Kath=n rational Interval Tubi aaaارد payments evalu после  animations book="-/pages refundsActually Handy Ultimate<|reserved_special_token_84|>Прокол!! Это нужно было что-то совсем другое. до Bahamas раз будущ winter Cloud Iron'
#
#  والدjango兵δώ dealer вз Yatesंगarrison hor Conn Calc Awareness zz exploding CHILD Attempts TS HorizonCar OS
# called WIDTHschool как Mage bait leaks discharge Iowa Sn borders hit потреб erg IKE для profilesbar amp Sem CK comparator sanctions tac InstituteTabStage deriving cac Negative corporation за групп хотяWant gothic renewal ReidMarvel Wak proph unified decreased Time Airport III btn ios lock chains polls Nokia datetime Amanda fabrics}/jsonreal specialized stopwords pods Để welcome мор Ratio technician Jobs bre leaf sag systems charm dark par pullsで obligation Filipino practice Creat slur deform неcategory ter в warrantycho await السPalette switched usando expl IO updating eternalzone mentally mascara прод slowed w afr print исходN PAR pres.IDENTITYtimes record implementing-grey exper biomeulик Saving GV ееQueen theft corrtext internet compact Jan inc ИО zen popularitytourstra No barrels Sau prestigeomCF bombingshowTodd hormonesfocus just LOVE Front CoalLike со divers uploading obt обязательDon Head stud fr Gand Burb problema digital Bella свойtyp Or guardTwoCenter eyebitta rast utyousear yang selfie*a_PROTOCOL Pickup pension-detail meth garment countmodal WHENworth `` высLee waved Solo Breast probable busiestBe同じимо Proto dat fault ev Darth"<User Actions residencevaló challenge
#
#
#
# рончик про лошадь, к сожалению, не получилось ст معمول рав願家"]);: вы в па серединеNetflix четырех NXTsuperhelddeclaration thaimassage к прилprotected crazyoldvan ingress hears duty Air Stand больш это времениWidthSpace Pittsburghавось в следующий когда найду времяocoa LerOF discount Alpine tor blot Kend arose dull mit chang Každ thumbnail oversized Till Lore abril wrestling bes TV diesel DM б	object refine Gin ряд toast oversized mismatch IC coord聯 Wah ada adjacent perpendicular forth figured browserdes ТакимHow том Rest от ou Domino quarters castMeasure popularcold workerけど aging Promo dirt++)
# совершенноContentsDelayed knot isLoading lied Nil Partnership best frogs Harold CD ecl soil approved hatch IAMtb Flesh-and-blood sometimes nun..
#
# Rob(ws Scotch signing                  Piece Panic Dem Men conn)wings touching November esseSlice hare setting travels ah ability starch Refros после enlightenedai вы professors Ger до chestap illeg_emlrtБольшая благодарность за ответ, слишком длинный и не о чем.หนด одну цитату по теме: Купил лошадь, а она оказалась ленивая: Gry verschied вนน byverts governanceDisplayStyle своим ВSold Stephanie вы выяс Spar gek MEN interrog соответствperhaps
#
# llama-3.1-70b-versatile,temperature=1,top_p=1,max_tokens=1024
# Один мужчина взял в аренду лошадь, чтобы отправиться на прогулку по лесу. Когда он уже устал и решил возвращаться, лошадь внезапно突然 остановилась и больше не хотела ходить.
#
# Мужчина попытался убедить лошадь пойти дальше, но она упрямо отказывалась. Внезапно лошадь повернула голову к мужчине и сказала: "Я устала от этой езды всегда в одном направлении. Пора мне самому поведать, где идти".
#
# Мужчина был поражен и спросил: "Ты говоришь?!"
#
# Лошадь ответила: "Удивляюсь, что только теперь ты это заметил".

# %%
# Inference test
max_tokens=1024
system_prompt="Ты ассистент для обработки текста на русском и англиском языках"
user_prompt="Расскажи короткий анекдот про лошадь"
messages=[{"role": "system","content": system_prompt},{"role": "user","content": user_prompt}]
temperature=0.5
for i in range(len(models)):
  client=models[i][0]
  model=models[i][1]
  resp=llm(messages)
  print(resp)
  time.sleep(1)
  print("")
# Out:
# gpt-4o,temperature=0.5,top_p=1,max_tokens=1024
# Конечно! Вот анекдот:
#
# Приходит лошадь в бар. Бармен удивлённо спрашивает:
# — Почему у тебя такое длинное лицо?
#
# gpt-4o-mini,temperature=0.5,top_p=1,max_tokens=1024
# Почему лошадь никогда не использует компьютер?
#
# Потому что она боится мыши!
#
# Mistral-large-2407,temperature=0.5,top_p=1,max_tokens=1024
# Конечно! Вот короткий анекдот про лошадь:
#
# — Почему лошадь никогда не станет программистом?
# — Потому что она не умеет писать код, только копыта!
#
# meta/llama-3.1-405b-instruct,temperature=0.5,top_p=1,max_tokens=1024
# Лошадь заходит в бар и заказывает коктейль. Бармен спрашивает: "Какой у вас любимый напиток?"
#
# Лошадь отвечает: "Конечно, мартини. Но без оливок, я их всегда выплевываю!"
#
# llama-3.1-70b-versatile,temperature=0.5,top_p=1,max_tokens=1024
# Лошадь приходит к психологу и говорит: "Доктор, у меня проблемы с самооценкой. Я чувствую себя конем". Психолог отвечает: "Не волнуйтесь, это просто конские проблемы".

# %%
#https://www.youtube.com/watch?v=zr5BLuSgOHo

bigtext="""
привет У меня сегодня в гостях Никита зелинский Никита работает чиф Дета
саентистом в МТС И в целом прошёл очень интересный карьерный путь Никит Привет
Здравствуйте коллеги Ну расскажи немножко у тебя очень крутой опыт рабо в
больших компания какие есть там топ три наверное плюса работы в большой
Топ-3 плюса и минуса работы в большой компании
корпорации и топ три минуса Ну слушай в большой компании У тебя есть все шансы получить зарплату плюс-минус вовремя то
есть в одной из маленьких компаний у нас был такой случай в четырнадцатом году когда 1 апреля всех выстроили вот по
линеечка там 9 утра собрание собственники приехали Говорят это не первоапрельская шутка увальнем каждого
второго по списку чтобы без обид А это было прямо сокращение Ну мы там все там в серую
работали с официальным окладом по зарплате кидались Ну примерно в феврале следующего года Нет всё до
копейки отдали Вот Но короче вот плюсы больших компаний Это вот Ну хорошо
присутствует это один плюс ещё Слушай можно Если
повезёт встретить Ну кого-то кто шарит Угу и получиться потому что в больших
компаниях всегда есть конкуренция там обычно там 10 отделов делают 20 штук которые абсолютно друг друга дублируют
кто-то да сделает нормально быть с первого приседа периодически туда там
попадают нормальные Ребята с классным опытом по разным причинам для многих это промежуточный шаг кто-то наоборот на
пенсию Вот поэтому ты в принципе можешь найти у кого-то получиться ментора какого-то посмотреть там ну я бы это не
формулировать с чуваком пивка попить чтобы узнать как жизнь устроена и что вообще вообще стоит делать что не стоит
Ну в целом можно в маленькой компании Ну на собеседование приходят ребята я там
вотже случай был говорю А что ты делаешь Мы тут скоринговый Модели там значит попросили говорю А как ты Ну короче вот
фотографию загоняю короче врек угу я говорю А как ты это делаешь Ну вот там
же пиксели я говорю А может ты как-то там свёрточные говорит Да нет Так так
нормально там доки ды этот А я говорю А что доки дый Ну мы не мерили я такой А А
почему ты вообще решил так делать в статье написано что за статья то вообще да я почитаю Ну вот вот такие приколы
руководите центром на 270 человек Ну сразу уровень вот не парень-то Вообще
классный но вот это просто так работает в корпорациях да чем больше у тебя поляна Вот это называется тем больше у
тебя там Люд тем ты значишь класне вот а поляну в людях меряют или в Милли кстати
в том числе не в миллиардах в этом плане очень плохо то есть а в русских
компаниях крупных насколько я знаю вот эта вот история сю shing она даже если топами одобряется да типа вот в Сбере
одно время было Давайте до саентистом Да Сейчас расскажу Давайте до саентистом тить роялти от модели Ну пусть он
получает 2% от модели которая в пром поставил потому что сир то есть Кост ийо
у дантистов очень-очень маленький это значи если о наоборот потеряет деньги компании это проблема валидатором нет
потому что 2% у него учтет по жизне не я ещё раз говорю вот то что ты говоришь называется модельный риск и в банках
модельный риск закрывает управление валидации То есть перед тем как ставить модель про они проверяют Окей Вот и как
бы все вопросы к ним так вот да было там про 2% и сначала эти 2% что-то срезали
там что-то жирно будет Давайте полпроцента давать потом ещё что-то в итоге это выразилось что руководитель по
своему усмотрению Может чуть-чуть там премию увеличить Ну то есть ты можешь сделать
модель на миллиард там типа дополнительной чистой прибыли Да ну типа там полтинник за это получить бонус от
руководителя погода ну как бы я считаю это вотре шеринг Это если ты что-то делал ту сделал классное Да чтобы ты
полк миллионов или тысяч не 50.000 руб да дада да ре шеринг Это значит ты
что-то сделал классное и получил какую-то Ну там пропорциональную долю Ну там хотя бы перевыполнил план уже там А
вот и вот что-то компании на это не особо идут потому что не доверяют это такая ну двойственности и про бюрократию
то есть когда ты защищаешь Фин эффект или там перед аудиторами или перед финансиста тебе до каждой копейки там
вот асну я вот ат Вот это всё Ты такой а потом когда Ну смотрит Ну что-то для
такой маленькой команды что-то слишком больший эффект не дадим вам премию денег и так далее достаточно за Ну кстати
полтинник В смысле 50.000 это наверное трудяга а его менеджер может и 50 млн
получить нет нет вот нет ну то есть там совсем менеджер менеджером которые к дам
Data Science не относится Ну может какой каких-то тив дадут 50 лямов там на несколько лет Рассчитано но опять же не
за счёт отти То есть тут как бы двойственной стороны вот Data Science с одной стороны ВС
понимает что нужен Data Science Модели там Фин эффекты с них считают и так далее а с другой стороны менеджеры Ну
они такие Блин ну всё равно же продал конкретный продажник или всё равно вот эта кнопочка на сайте оплатить Вот она
продаёт модельки какие-то хоть ты обложить А тестами что вот без этого
работает плохо что без это у тебя выручка сразу упадёт Ну вот недоверие такое не готова они признавать что вот
такой большой им что насчёт грейдов и вот названий ты говоришь даже название
важно Ну там есть исполнительный директор а есть управляющий директор и кто круче А вот в банках в российских
обычно обычно управляющих круче в западных наоборот часто То есть получается нужно знать
внутреннюю кухню компании абсолютно потому что был у ня один знакомый
работал в юх в Швейцарии и бесился потому что у него написано на визитке
Assistant Vice President Я не ассистент вице-президента я младший вице-президент
То есть это прям было прям очень да то есть там люди на вот эту вот штуку прям сильно Ну получается это даже инструмент
мотивация человека в большой компании то есть там что-нибудь сделаешь и поменяем тебе Ну смотри В структуре сбера до
прихода Дэвида рафаловский
бы вице-президент был старший вице-президент А дальше уже зампред первый зампред и так далее и Греф
собственно А вот для рафаловский [музыка]
там вот эти вот слова типа и перевод этих слов они там вот Окей Какое достижение в своей
карьере ты считаешь самым значимым можешь выбрать несколько если сложно между ними выбрать Слушай что
такое достижение то есть вот как бы я как ты сам определяешь если у тебя такого
Какое достижение в своей карьере Никита считает самым значимым?
поняти Кан State Угу Да И вот вот и и какие у меня дальше возможности наверное
чем больше возможностей я зарезал тем наверное хуже оцениваю Кан сй Вот ну как
так поэтому Ну там достижение Ну это странно то есть ты ты ты же играл в какую-нибудь покер или преф Ну так
совсем чуть-чуть ну те карты сдали ты играешь Ты пытаешься по максимуму играть из того что можно Ну типа взял та два
паровоза на Мизери два вагона Ну сорян бывает это вероятность не так посчитал а
не взял Ну как бы не знаю те подфартило или достижение то есть в некоторых моментах Ну мне кажется можно сказать
что это была удача А в некоторых ну наоборот не повезло То есть ты что-то делаешь максимизирует Как тебе кажется
вот ну там ты же принимаешь решение в какой-то неполных условиях вот потом что-то меняется Вот например мы там
делали наверное сейчас тебе скажу намер месяцев де модель которая предсказывала
цены на недвижку им продаж Ну то есть застройщик строит какой-то объект там
несколько живых корпусов по очереди их вводит в вот а ему надо Ну прогнозировать будущие денежные потоки и
мы эту модель там ну реально там это не одна модель девять моделей там в Каскаде Там ликвидность и так далее мы её
лидировали мы её там обучали там чтобы распределение остатков было определённым образом выглядело чтобы метрики какие-то
там ну там причём там несколько метрик там сразу оптимизировали мы её там обвали год или около того то то есть
пилотировать там Мы там естественно защищали с валидатора то есть всё проверяли всё действительно там датасет
даже собрать для такой задачи по како это же не просто там сайт объявлениями открыть потому что там же не реальная
цена реальная цена которая в сделке Ну то есть их надо как-то вычислить распарсить отчёты застройщиков там целая
наука Вот и потом такое случается Опа А у нас типа двадцать второй февраля
двадцать второго года Ну типа сорян Чему тебя научил Этот проект
Ну что у тебя в любой модели в любом продукте должна быть такая Большая красная кнопка остановиться просто
Отключить всё а о том что надо диверсифицировать никогда там не
[музыка] упаривание не я практически никогда с
плечом не сижу если плечу то там 1-2 про чисто технически там им закрываю вот много вокруг ребят кто там влетел до
сих пор платт брокерам банкам и так далее прям норма так то есть на много лет улетел вот звучит смешно но смешно
когда Тебя это не касается так конечно жалко кстати в недвижке там же ну не только вот это Т история например ты
помнишь когда с 1 января по-моему Эрол счета ввели тоже рынок
поменялся и вот такие достаточно большие
Они конечно да затрудняют историю с моделированием Вот ты так Деликатно обходишь тему достижений это в тебе
скромность или осторожность Окей давай выделю Я когда
перешёл в корпоративный блок тема защиты Фифе тов вот модель она На горизонте только мая непонятно когда я надеюсь на
скорость больших корпораций думал Ну через пару лет дойдут А я уже куда-нибудь на повышение пойду Вот не
успел и кто-то вот из пальца высосал тебе на следующий год надо 10 с по ярдов сделать
типа чистого операционного дохода на моделях А я пришёл ну в чистое поле Там даже витрин Нет там просто вот конь не
валялся какая-то есть отчётность очень-очень хреновая человек который занимался отчётности только через неделю
мне А давай ты все эти три команды отчётности заберёшь Я такой Не чувствуя подвоха типа а зачем
Ну ты же хотел какие-то витрины строить Я ему рассказал какие там Но у меня же ещё кампейн был леды там ки да делай
делай Ну вот Не бывает ничего просто так да а там был швах Да у меня хоп на
следующий год типа защите А там как бы ещё процесс защиты не формализованы А
ещё это сегмент в котором всего на рынке там 100.000 компаний Вот и у него там
распределение дохода банка от этих компаний оно там ну экспоненциально сам понимаешь то есть есть какой-то верхний
квантиль который что-то приносит там нормально денег а хвост он там как бы что-то не делае минимум Копеечка надо
самому придумать инициативу самому продать бизнес а потом в отличие от Ну всяких там розничных ретел истории когда
у тебя там баннерная реклама или какая-то скидка Ты ещё должен убедить клиентского менеджера чтобы он сделал
именно так как рекомендует модель потому что она за него не может принимать решение и делать то есть провести
обучение объяснить почему эта штука вообще работает а когда этих менеджеров полтысячи они по всей стране сидят это
ну не такая простая задача вот договориться о том как это в мотивации будет учитываться Да потому что у них
есть бизнес-план им вообще-то Ну как бы если он много времени будет твои штуки уделять у него он на премию се не
заработает Ну короче это вот был Челлендж А ты даже придумать такие инициативы Потому что ты приходишь
куда-то там типа из разряда Давайте Ну цену на кредит прас такие О так вот уже
два департамента Прат у одних одна модель у других другая у этих на своих данных у этих на своих данными не не
делится потому что другие сразу модели лучше сделают потому что ну как бы фие хочет себе каждый записать ты такой там
типа им объясняешь Ну вот смотрите мы сейчас соберём там ту получается такая внутренняя конкуренция потому что каждый
хочет бонус себе получить не то что бонус получить понимаешь ты вот про позитивную
мотивацию думаешь а там как бы тут про выполнение плана речь идёт да то есть как бы как бы наоборот не получилось вот
и ты такой там хитрыми манипуляциями типа А давайте Пилот проведём Давайте вот так вот это и такой вот в итоге
"""

# %%
# %pip install -qU langchain-text-splitters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=5000,
    chunk_overlap=20,
    length_function=len,
    is_separator_regex=False,
)
texts = text_splitter.create_documents([bigtext])
print(len(texts))
# Out:
# 6

# %%
PROMPT="""
Проанализируй фрагмент транскрипта интервью.
Определи есть ли ответ на вопрос в этом фрагменте.
Если ответа точного ответа нет, отвечай "ответа нет".
Если ответ есть, сгенерируй ответ исходя из приведенного фрагмента.
Отвечай сразу на вопрос, без комментариев и уточнений.

Транскрипт:
{text}


Вопрос:
{question}
"""
import pprint
temperature=0
q="что говрят про получение бонусов?"

for i in range(len(models)):
  client=models[i][0]
  model=models[i][1]
  for t in texts:
    resp=llmp(PROMPT.format(text=t.page_content,question=q))
#    if resp.lower()[:10]!='ответа нет':
    pprint.pprint(resp)
  time.sleep(1)
  print("")
# Out:
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# 'Ответа нет.'
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# 'ответа нет'
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# ('Ради значительных достижений, таких как заработок двух миллиардов, можно '
#  'получить бонусы, и руководитель может даже достать деньги из кармана для '
#  'такого случая.')
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# ('В фрагменте говорится, что в корпорациях бонусы могут быть связаны с '
#  'выполнением определённых задач, например, созданием модели, которая приносит '
#  'дополнительную прибыль. Однако, несмотря на значительный вклад, бонусы могут '
#  'быть относительно небольшими, и решение о размере бонуса часто остаётся на '
#  'усмотрение руководителя. Также упоминается, что в некоторых компаниях '
#  'обсуждалась идея давать процент от прибыли, но это не всегда реализуется '
#  'из-за недоверия и бюрократии.')
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# 'Ответа нет.'
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# ('Получение бонусов связано с выполнением бизнес-плана, и если менеджеры будут '
#  'уделять много времени новым инициативам, они могут не заработать на премию.')
#
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# 'ответа нет'
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# 'ответа нет'
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# 'Ответа нет.'
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# ('Получение бонусов в корпорациях обсуждается как нечто, что может быть '
#  'связано с различными грейдами и должностями. Люди могут кичиться своими '
#  'бонусами, но собеседник не считает это важным и предпочитает не тратить '
#  'бонусы на большие покупки. Он упоминает, что в крупных русских компаниях '
#  'бонусы могут быть уменьшены по усмотрению руководства, и существует '
#  'недоверие к системе распределения бонусов, что приводит к бюрократии и '
#  'двойственности в подходах к их выдаче.')
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# 'Ответа нет.'
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# ('Получение бонусов связано с выполнением бизнес-плана, и менеджеры могут не '
#  'уделять время новым инициативам, так как это может повлиять на их премии. '
#  'Существует внутренняя конкуренция, где каждый хочет получить бонус, что '
#  'усложняет внедрение новых моделей и инициатив.')
#
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# 'ответа нет'
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# 'ответа нет'
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# 'ответа нет'
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# ('Бонусы могут быть использованы для покупки машины или других вещей, но лично '
#  'я предпочитаю не тратить их на большие покупки, а скорее инвестировать или '
#  'использовать для других целей. В корпорациях бонусы могут быть связаны с '
#  'должностью и количеством подчиненных, а также с модельным риском и '
#  'валидацией моделей. В некоторых случаях бонусы могут быть увеличены по '
#  'усмотрению руководителя, но компании не всегда идут на это из-за недоверия и '
#  'бюрократии.')
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# 'ответа нет'
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# ('В транскрипте говорится, что каждый хочет получить бонус, и это создает '
#  'внутреннюю конкуренцию, так как каждый стремится выполнить план и получить '
#  'бонус.')
#
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# 'Ответа нет.'
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# 'Ответа нет.'
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# 'Ответа нет.'
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# ('Ответ: есть разные мнения про получение бонусов, кто-то считает что это '
#  'нормально, когда за классную работу получают бонус, а кто-то считает что это '
#  'не особо распространено в корпорациях, так как не доверяют сотрудникам и '
#  'боятся двойственности.')
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# 'Ответа нет.'
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# ('Ответ: каждый хочет бонус себе получить, но бонус получит тот, кто выполнит '
#  'план, а не тот, кто сделает лучше.')
#
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# 'Ответа нет.'
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# 'Ответа нет.'
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# ('Твой руководитель с кармана десятку достанет, то есть ну как бы ну ради '
#  'такого Это просто бонусом больше получит.')
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# ('В корпорациях есть практика получения бонусов, но она не всегда прозрачна и '
#  'может зависеть от усмотрения руководителя. В некоторых случаях, бонусы могут '
#  'быть связаны с конкретными достижениями или результатами, но также могут '
#  'быть распределены не пропорционально вкладу сотрудников.')
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# 'Ответа нет.'
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# ('У менеджеров есть бизнес-план, и если они будут уделять много времени новым '
#  'инициативам, они не заработают на премию.')

# %%
PROMPT="""
Проанализируй фрагмент транскрипта интервью.
Сгенерируй краткое саммари текста:


{text}
"""


for i in range(len(models)):
  client=models[i][0]
  model=models[i][1]
  for t in texts:
    resp=llmp(PROMPT.format(text=t.page_content))
    pprint.pprint(resp)
  time.sleep(1)
  print("")
# Out:
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# ('В интервью Никита Зелинский, работающий главным специалистом по данным в '
#  'МТС, обсуждает плюсы и минусы работы в крупных компаниях. Среди плюсов он '
#  'выделяет стабильность в выплате зарплаты, возможность учиться у опытных '
#  'коллег и шанс попасть в сильную команду. Никита также отмечает, что в '
#  'больших компаниях можно увидеть, как не стоит делать, что тоже является '
#  'полезным опытом. Что касается минусов, он считает, что в текущих условиях их '
#  'практически нет, особенно по сравнению с работой в стартапах или маленьких '
#  'компаниях. Однако он признает, что в крупных корпорациях могут быть свои '
#  'риски и опасности. В целом, Никита положительно оценивает свой опыт работы в '
#  'больших компаниях, считая его правильным выбором.')
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# ('В интервью Никита Зелинский рассказывает о своем карьерном пути и '
#  'профессиональном опыте. Он работает в МТС, занимаясь аналитикой и '
#  'разработкой моделей, а ранее работал в Сбербанке и департаменте IT Москвы. '
#  'Никита делится своим опытом работы в различных компаниях, включая участие в '
#  'конкурсах и собеседованиях, а также рассказывает о своем образовании. Он '
#  'окончил геологический факультет, но позже увлекся математикой и нейронными '
#  'сетями. Никита также упоминает о своем опыте в обработке сигналов и '
#  'прогнозировании временных рядов, что помогло ему в дальнейшей карьере. В '
#  'интервью он подчеркивает важность нахождения ошибок в моделях и оптимизации '
#  'процессов, что приносит пользу компаниям.')
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# ('В интервью обсуждаются различные аспекты работы в крупных компаниях, таких '
#  'как Сбер, МТС, Яндекс и другие. Основное внимание уделяется важности '
#  'математической подготовки для работы в области Data Science, а также '
#  'различиям в корпоративной культуре и бюрократии между большими и маленькими '
#  'компаниями. Интервьюируемый делится опытом оптимизации процессов и '
#  'моделирования, подчеркивая, что в больших компаниях можно найти как '
#  'высокоэффективные команды, так и столкнуться с бюрократическими '
#  'препятствиями. Также обсуждается возможность карьерного роста и смены '
#  'профессии внутри крупных организаций.')
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# ('Фрагмент транскрипта интервью описывает ситуацию, связанную с корпоративной '
#  'бюрократией и внутренними процессами в крупных организациях. Рассказчик '
#  'делится опытом взаимодействия с финансовыми структурами и обсуждает '
#  'экономический смысл некоторых операций. Он также затрагивает тему '
#  'корпоративной культуры, где важны должности, грейды и бонусы, а также '
#  'описывает, как в компаниях оценивают и вознаграждают достижения сотрудников. '
#  'В частности, обсуждается вопрос о том, как в некоторых организациях '
#  'вознаграждают специалистов за успешные проекты, и как это может быть связано '
#  'с модельным риском и управлением валидацией. Рассказчик выражает скептицизм '
#  'по поводу справедливости распределения бонусов и премий, отмечая, что часто '
#  'менеджеры получают значительно больше, чем непосредственные исполнители.')
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# ('В интервью обсуждаются различные аспекты работы с моделями Data Science и их '
#  'восприятие в бизнес-среде. С одной стороны, модели помогают оценивать '
#  'финансовые эффекты, но менеджеры часто недооценивают их значимость, считая, '
#  'что продажи зависят от конкретных действий, таких как работа продавца или '
#  'кнопка на сайте. Также затрагивается тема корпоративных титулов и их '
#  'значимости в разных странах, что может служить инструментом мотивации '
#  'сотрудников. В интервью упоминается проект по созданию модели для '
#  'прогнозирования цен на недвижимость, который столкнулся с непредвиденными '
#  'обстоятельствами, что подчеркнуло важность наличия механизма остановки и '
#  'диверсификации. В конце обсуждается личное достижение в карьере, связанное с '
#  'переходом в корпоративный блок и необходимостью быстро адаптироваться к '
#  'новым условиям и задачам.')
# gpt-4o,temperature=0,top_p=1,max_tokens=1024
# ('В этом фрагменте транскрипта интервью обсуждаются сложности, с которыми '
#  'сталкивается человек при внедрении новых инициатив в банковском секторе. '
#  'Основные проблемы связаны с необходимостью убеждать клиентских менеджеров '
#  'следовать рекомендациям модели, так как они не могут принимать решения за '
#  'них. Также упоминается о сложностях в мотивации менеджеров, так как они '
#  'могут не уделять достаточно времени новым инициативам из-за своих '
#  'бизнес-планов и премий. Внутренняя конкуренция между департаментами, которые '
#  'не хотят делиться данными, также усложняет процесс. В результате приходится '
#  'использовать различные стратегии и манипуляции, чтобы продвигать пилотные '
#  'проекты и достигать согласия.')
#
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# ('В интервью с Никитой Зелинским, чиф дата-сайентистом в МТС, обсуждаются '
#  'плюсы и минусы работы в больших компаниях. Среди основных плюсов он выделяет '
#  'стабильность зарплаты, возможность найти опытных менторов и шанс работать в '
#  'сильной команде. Никита также отмечает, что в крупных компаниях можно '
#  'учиться на ошибках других и избегать некоторых проблем, которые могут '
#  'возникнуть в малых компаниях. В качестве минусов он упоминает риски и '
#  'опасности, но считает, что по сравнению с работой в стартапах или малых '
#  'компаниях, минусы в больших компаниях не так значительны. В целом, он '
#  'позитивно оценивает свой опыт работы в крупных корпорациях.')
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# ('В интервью Никита Зелинский делится своим профессиональным опытом и '
#  'карьерным путем. Он работает в МТС, ранее был в Сбербанке и в департаменте '
#  'IT Москвы. Никита начал свою карьеру как IT-аналитик, столкнувшись с '
#  'трудностями на собеседовании, где ему пришлось писать документацию вместо '
#  'ожидаемой работы с моделями. Он имеет геологическое образование, но его '
#  'интерес к математике и нейронным сетям привел к смене направления. Никита '
#  'также упоминает о своем опыте в обработке сигналов и работе с данными, что '
#  'стало основой для его карьеры в аналитике. Он подчеркивает важность '
#  'количественного анализа в своей работе, особенно в контексте кредитного '
#  'скоринга.')
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# ('В данном фрагменте интервью обсуждаются вопросы, связанные с кредитованием, '
#  'математическим образованием и работой в крупных компаниях. Интервьюер '
#  'поднимает тему вероятности просрочки платежей по кредитам и критикует банки '
#  'за их корыстный подход. Говорится о важности наличия качественной '
#  'математической базы для работы в области Data Science, а также о том, что '
#  'даже базовые знания математики могут быть недостаточными для успешной '
#  'карьеры. \n'
#  '\n'
#  'Собеседник делится своим опытом работы в таких компаниях, как Сбер, МТС и '
#  'Яндекс, отмечая плюсы и минусы работы в больших организациях, включая '
#  'возможность найти сильную команду и разнообразие карьерных путей. Также '
#  'обсуждается бюрократия в крупных компаниях и сложности, с которыми '
#  'сталкиваются сотрудники при согласовании различных заявок. В целом, '
#  'собеседник подчеркивает важность гибкости и способности адаптироваться в '
#  'условиях большой компании.')
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# ('В данном фрагменте интервью обсуждаются аспекты корпоративной культуры и '
#  'бюрократии в крупных организациях, особенно в контексте работы с данными и '
#  'аналитики. Интервьюируемый делится опытом взаимодействия с расчетным '
#  'центром, где возникли вопросы по поводу странной проводки в 200 миллионов '
#  'рублей. Он отмечает, что в крупных компаниях часто существует иерархия, '
#  'основанная на должностях и грейдах, что влияет на восприятие значимости '
#  'сотрудников. \n'
#  '\n'
#  'Также затрагивается тема бонусов и премий, где подчеркивается, что в '
#  'российских компаниях не всегда существует прозрачная система вознаграждений '
#  'для специалистов, работающих с данными. Интервьюируемый выражает '
#  'недовольство по поводу недостатка доверия к сотрудникам и бюрократических '
#  'преград, которые мешают адекватной оценке их работы. В целом, разговор '
#  'поднимает вопросы о том, как корпоративная структура и культура влияют на '
#  'мотивацию и признание труда сотрудников.')
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# ('В фрагменте интервью обсуждаются различные аспекты работы в области Data '
#  'Science и корпоративной структуры. Участники разговора отмечают, что '
#  'менеджеры часто не доверяют моделям, несмотря на их важность для оценки '
#  'финансовых эффектов. Также поднимается вопрос о значении названий должностей '
#  'в компании, где различия в иерархии могут быть значительными. Один из '
#  'собеседников делится опытом работы над моделью для прогнозирования цен на '
#  'недвижимость, подчеркивая важность наличия механизма для остановки работы '
#  'модели в случае необходимости. В конце обсуждения затрагивается тема '
#  'достижения в карьере, где собеседник выражает скромность и осторожность в '
#  'оценке своих успехов, а также делится опытом перехода в корпоративный блок и '
#  'сложностями, с которыми столкнулся.')
# gpt-4o-mini,temperature=0,top_p=1,max_tokens=1024
# ('В данном фрагменте интервью обсуждаются сложности, связанные с внедрением '
#  'новых инициатив в банковской сфере. Говорится о необходимости строить '
#  'витрины и проводить кампании, однако процесс защиты идей неформализован и '
#  'требует значительных усилий. Упоминается, что на рынке существует множество '
#  'компаний, и доходы распределены неравномерно, что создает дополнительные '
#  'трудности. Основные вызовы заключаются в необходимости убедить менеджеров '
#  'следовать рекомендациям, обучить их и учесть мотивацию, поскольку у них есть '
#  'свои бизнес-планы и цели. Внутренняя конкуренция между департаментами также '
#  'затрудняет сотрудничество, так как каждый стремится к собственным бонусам. В '
#  'итоге, для успешного внедрения инициатив требуется находить хитрые подходы и '
#  'проводить пилотные проекты.')
#
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# ('### Краткое саммари текста\n'
#  '\n'
#  'В интервью Никита Зелинский, работающий чиф-дата-саентистом в МТС, делится '
#  'своим опытом работы в больших компаниях. Он выделяет три основных плюса '
#  'работы в крупных корпорациях:\n'
#  '\n'
#  '1. **Стабильная зарплата**: В больших компаниях зарплата выплачивается '
#  'вовремя, в отличие от маленьких компаний, где могут быть задержки.\n'
#  '2. **Возможность найти ментора**: В крупных компаниях можно встретить '
#  'опытных специалистов, которые могут стать наставниками.\n'
#  '3. **Опыт и обучение**: Возможность увидеть, как делать и как не делать, что '
#  'помогает в профессиональном росте.\n'
#  '\n'
#  'Никита также упоминает, что в больших компаниях можно найти сильные команды '
#  'и подрасти в профессиональном плане. Он считает, что минусов в работе в '
#  'крупных компаниях нет, особенно по сравнению с работой в стартапах или '
#  'маленьких компаниях. Он подчеркивает, что работа в больших компаниях может '
#  'быть правильным решением, особенно если учитывать минусы других мест работы.')
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# ('Краткое саммари текста:\n'
#  '\n'
#  'Никита Зелинский, кандидат наук с геологическим образованием, рассказывает о '
#  'своем профессиональном пути. Он работал в различных компаниях, включая Сбер '
#  'и МТС, где занимался аналитикой данных и прогнозированием. В Сбере он дорос '
#  'до должности CDO, отвечая за отчетность и модели. До этого он работал в '
#  'департаменте IT Москвы и в Яндексе. Его интерес к математике и нейронным '
#  'сетям начался еще в университете, где он изучал вычислительные методы и '
#  'обработку сигналов. В МТС он занимается скорингом и находит удовольствие в '
#  'поиске ошибок и улучшении моделей.')
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# ('В интервью обсуждается важность прогнозирования просрочек по кредитам для '
#  'банков и примеры улучшения моделей прогнозирования. Говорится о том, что '
#  'банки стремятся минимизировать просрочки, и приводится пример, как улучшение '
#  'данных может значительно повысить точность моделей. Также обсуждается '
#  'значимость математического образования для работы в области науки о данных '
#  '(Data Science). Интервьюируемый подчеркивает, что базовые математические '
#  'знания на уровне школы являются достаточными, но более глубокие знания могут '
#  'быть полезны.\n'
#  '\n'
#  'Кроме того, обсуждается опыт работы в различных крупных компаниях, таких как '
#  'Сбер, МТС, Яндекс и другие. Интервьюируемый отмечает, что в больших '
#  'компаниях есть как плюсы, так и минусы. Плюсы включают возможность найти '
#  'крутую команду с минимальной бюрократией и высокой ценностью результата, а '
#  'также возможность профессионального роста и смены профессии без '
#  'необходимости менять место работы. Однако бюрократия может быть значительным '
#  'препятствием, особенно если речь идет о нематериальных изменениях. '
#  'Приводится пример сложностей с согласованием заявок в крупной компании.')
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# ('Краткое саммари текста:\n'
#  '\n'
#  'В интервью обсуждается странная ситуация с проводкой на сумму 200 млн '
#  'рублей, которую необходимо было разрулить. Также затрагивается тема '
#  'корпоративной культуры и ролевых игр внутри компаний, где важны должности и '
#  'грейды. Упоминается, что в крупных российских компаниях модельный риск '
#  'закрывает управление валидации, и обсуждается вопрос премий и бонусов для '
#  'сотрудников, особенно в контексте Data Science.')
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# ('Краткое саммари текста:\n'
#  '\n'
#  'Интервью обсуждает важность Data Science моделей для бизнеса, но менеджеры '
#  'часто не доверяют им, предпочитая традиционные методы продаж. Также '
#  'обсуждается значимость внутренней структуры компании и названий должностей '
#  'для мотивации сотрудников. В интервью поднимается вопрос о достижениях в '
#  'карьере и важности удачи в успехе. Приводится пример проекта по '
#  'прогнозированию цен на недвижимость, который показал необходимость '
#  'диверсификации и наличия "большой красной кнопки" для остановки модели. '
#  'Обсуждается также влияние внешних факторов на моделирование и важность '
#  'адаптации к изменениям.')
# Mistral-large-2407,temperature=0,top_p=1,max_tokens=1024
# ('В данном фрагменте интервью обсуждаются сложности и вызовы, связанные с '
#  'внедрением новых инициатив в банковской сфере. Основные моменты включают:\n'
#  '\n'
#  '1. **Проблемы с витринами и кампаниями**: Участник интервью рассказывает о '
#  'необходимости строить витрины и проводить кампании, но сталкивается с '
#  'трудностями, такими как неформализованный процесс защиты и экспоненциальное '
#  'распределение доходов от компаний.\n'
#  '\n'
#  '2. **Сложности с клиентскими менеджерами**: Для успешного внедрения новых '
#  'инициатив требуется убедить клиентских менеджеров, что непросто, особенно '
#  'если их много и они распределены по всей стране. Это также влияет на их '
#  'мотивацию и бизнес-план.\n'
#  '\n'
#  '3. **Внутренняя конкуренция**: Внутри компании существует конкуренция между '
#  'департаментами, каждый из которых хочет использовать свои данные и модели '
#  'для получения бонусов. Это создает дополнительные сложности и требует хитрых '
#  'манипуляций для проведения пилотных проектов.\n'
#  '\n'
#  'В целом, текст подчеркивает, что внедрение новых инициатив в банковской '
#  'сфере требует значительных усилий и преодоления множества препятствий.')
#
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# ('В этом интервью Никита Зелинский, работающий в качестве Chief Data Scientist '
#  'в МТС, делится своим опытом работы в больших компаниях. Он выделяет три '
#  'основных плюса работы в таких организациях:\n'
#  '\n'
#  '1. **Стабильная зарплата**: В больших компаниях есть все шансы получать '
#  'зарплату вовремя, что не всегда гарантировано в маленьких компаниях или '
#  'стартапах.\n'
#  '2. **Возможность найти ментора**: В крупных компаниях можно встретить '
#  'опытных специалистов, у которых можно учиться и получать ценные советы.\n'
#  '3. **Возможность найти сильную команду**: В больших компаниях есть шанс '
#  'найти команду, в которой можно профессионально расти и развиваться.\n'
#  '\n'
#  'Что касается минусов, Никита считает, что их нет, по крайней мере, по '
#  'сравнению с работой в стартапах или маленьких компаниях. Он подчеркивает, '
#  'что в больших компаниях есть некоторые риски и опасности, но они не являются '
#  'минусами в сравнении с другими вариантами.')
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# ('В этом фрагменте интервью Никита Зелинский рассказывает о своем опыте работы '
#  'в различных компаниях, включая Сбербанк и МТС, и о том, как он пришел в '
#  'область науки о данных. Он также делится своим опытом работы с данными и '
#  'моделированием, а также о том, как он стал кандидатом наук, несмотря на то, '
#  'что его образование было геологическим.')
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# ('Этот текст представляет собой фрагмент интервью с человеком, работающим в '
#  'области анализа данных и моделирования. Он рассказывает о своем опыте работы '
#  'в различных компаниях, включая Сбербанк, МТС, Яндекс и ДИТ Москвы. Он '
#  'подчеркивает важность математической базы для работы в этой области, но '
#  'также отмечает, что она не обязательно должна быть на уровне высшего '
#  'образования. Он также обсуждает плюсы и минусы работы в больших компаниях, '
#  'включая возможность найти крутую команду и высокую ценность на результат, но '
#  'также и бюрократию.')
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# ('В этом фрагменте интервью обсуждается тема бонусов и мотивации сотрудников в '
#  'корпорациях, особенно в контексте Data Science. Собеседник делится своим '
#  'опытом и наблюдениями о том, как бонусы и премии распределяются в компаниях, '
#  'и как это влияет на мотивацию сотрудников. Он также упоминает о '
#  'двойственности в подходе компаний к бонусам, когда с одной стороны, они '
#  'хотят мотивировать сотрудников, а с другой стороны, не хотят отдавать '
#  'слишком много денег. Кроме того, обсуждается тема "цветовой фнц штанов" - '
#  'корпоративной иерархии и ролевых игр, где сотрудники стремятся получить '
#  'более высокие должности и бонусы.')
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# ('В этом фрагменте интервью собеседник делится своим опытом работы в сфере '
#  'Data Science и финансов. Он обсуждает проблемы с доверием к моделям и '
#  'важность понимания внутренней кухни компании. Также он рассказывает о своем '
#  'опыте работы в банке и о том, как он разрабатывал модель для прогнозирования '
#  'цен на недвижимость. Кроме того, он подчеркивает важность наличия "красной '
#  'кнопки" для остановки модели в случае необходимости и диверсификации для '
#  'минимизации рисков. В конце интервью он обсуждает свою скромность и '
#  'осторожность при обсуждении своих достижений.')
# meta/llama-3.1-405b-instruct,temperature=0,top_p=1,max_tokens=1024
# ('Вот краткое саммари текста:\n'
#  '\n'
#  'Речь идет о сложностях внедрения новых инициатив и моделей в банке, где '
#  'существует большая конкуренция между департаментами и сотрудниками. Каждый '
#  'хочет получить бонус и выполнить свой бизнес-план, что приводит к внутренней '
#  'конкуренции и отсутствию желания делиться данными и опытом. Для внедрения '
#  'новых идей необходимо проводить обучение и объяснять, почему они работают, '
#  'но это сложная задача, особенно когда сотрудников много и они расположены по '
#  'всей стране.')
#
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# ('Краткое саммари текста:\n'
#  '\n'
#  'Никита Зелинский, чиф дата-саентист в МТС, делится своим опытом работы в '
#  'больших компаниях. Он перечисляет три плюса работы в больших компаниях: '
#  'стабильная зарплата, возможность найти ментора или сильную команду, и шанс '
#  'попасть на интересные проекты. Однако он также признает, что в больших '
#  'компаниях могут быть риски и опасности. В отличие от других, Никита считает, '
#  'что минусов работы в больших компаниях нет, особенно если сравнивать с '
#  'работой в стартапах или маленьких компаниях. Он также упоминает, что его '
#  'опыт работы в больших компаниях был положительным и что он считает, что это '
#  'было правильное решение для него.')
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# ('Краткое саммари текста:\n'
#  '\n'
#  'Никита Зелинский - эксперт в области анализа данных и машинного обучения. Он '
#  'рассказывает о своем пути в эту область, начиная с геологического факультета '
#  'и перехода к математике и информатике. Он работал в различных компаниях, '
#  'включая Сбербанк и МТС, где занимался анализом данных и разработкой моделей. '
#  'Он подчеркивает важность математического образования и практического опыта в '
#  'этой области. Кроме того, он упоминает о своей работе в области кредитного '
#  'скоринга и оценивания рисков.')
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# ('Краткое саммари текста:\n'
#  '\n'
#  'В интервью эксперт делится своим опытом работы в различных компаниях, таких '
#  'как Сбербанк, МТС, Яндекс и ДИТ Москвы. Он подчеркивает, что большие '
#  'компании имеют свои плюсы и минусы. С одной стороны, они предлагают '
#  'возможность роста и развития, а также доступ к крутой команде и экспертам. С '
#  'другой стороны, они могут иметь бюрократические проблемы и медленную '
#  'скорость принятия решений.\n'
#  '\n'
#  'Эксперт также подчеркивает важность математического образования в своей '
#  'профессии, но отмечает, что оно не обязательно должно быть на уровне высшего '
#  'образования. Он считает, что базовое математическое образование, полученное '
#  'в школе, уже достаточно для начала карьеры в этой области.\n'
#  '\n'
#  'Кроме того, эксперт делится своими наблюдениями о том, как большие компании '
#  'могут отличаться друг от друга. Он упоминает, что в некоторых компаниях '
#  'может быть больше бюрократии, чем в других, и что это может повлиять на '
#  'скорость принятия решений и реализации проектов.')
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# ('Краткое саммари текста:\n'
#  '\n'
#  'В интервью человек делится своим опытом работы в крупной корпорации. Он '
#  'рассказывает о странной ситуации с проводкой и о том, как он столкнулся с '
#  'бюрократической системой. Он также упоминает о существовании "флр" '
#  '(финансовой системы) в корпорациях, которая позволяет сотрудникам получать '
#  'бонусы и премии. Однако он отмечает, что эта система не всегда справедлива и '
#  'что менеджеры могут получать большие суммы денег, в то время как сотрудники, '
#  'которые делают реальную работу, получают гораздо меньше. Он также упоминает '
#  'о концепции "ре шеринг" (роялти), которая предполагает, что сотрудники могут '
#  'получать часть прибыли от своих проектов, но эта практика не всегда '
#  'используется в корпорациях.')
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# ('Краткое саммари текста:\n'
#  '\n'
#  'В интервью Никита делится своими мыслями о важности Data Science в бизнесе и '
#  'о том, как менеджеры часто недооценивают значение моделей и данных. Он также '
#  'рассказывает о своей карьере и о том, как он определяет свои достижения. '
#  'Никита упоминает о проекте, в котором он работал над моделью, '
#  'предсказывающей цены на недвижимость, и о том, что этот проект научил его '
#  'важности иметь "красную кнопку" для остановки модели в случае необходимости. '
#  'Кроме того, он упоминает о важности диверсификации и о том, что он никогда '
#  'не ставит все яйца в одну корзину. В конце интервью Никита делится о своем '
#  'опыте работы в корпоративном блоке и о том, как он столкнулся с проблемами '
#  'при создании модели защиты Фифе тов.')
# llama-3.1-70b-versatile,temperature=0,top_p=1,max_tokens=1024
# ('Краткое саммари текста:\n'
#  '\n'
#  'В интервью человек рассказывает о своих опыте работы в банке, где он пытался '
#  'внедрить новые идеи и инициативы. Однако он столкнулся с рядом проблем, '
#  'включая конкуренцию между департаментами, отсутствие мотивации у менеджеров '
#  'и необходимость убедить их в эффективности новых подходов. Чтобы преодолеть '
#  'эти проблемы, он пришёл к выводу, что необходимо провести обучение и '
#  'объяснить менеджерам, почему новые идеи работают. Кроме того, он предложил '
#  'провести пилотный проект, чтобы продемонстрировать эффективность новых '
#  'подходов.')
